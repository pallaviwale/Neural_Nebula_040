# %%
import pandas as pd

# %%
url="https://drive.google.com/file/d/1368WjSku3TfBzkJB1Q5a5-3TbFNDJAhQ/view?usp=sharing"
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
amsterdam_weekends = pd.read_csv(url)

# %%
amsterdam_weekends
# Out:
#      Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 0             0   319.640053     Private room        False          True
# 1             1   347.995219     Private room        False          True
# 2             2   482.975183     Private room        False          True
# 3             3   485.552926     Private room        False          True
# 4             4  2771.541724  Entire home/apt        False         False
# ..          ...          ...              ...          ...           ...
# 972         972   473.132894  Entire home/apt        False         False
# 973         973   491.645771  Entire home/apt        False         False
# 974         974  1812.855904  Entire home/apt        False         False
# 975         975   399.315727  Entire home/apt        False         False
# 976         976   728.798069  Entire home/apt        False         False
#
#      person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# ...

# %%
amsterdam_weekends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  977 non-null    int64
#  1   realSum                     977 non-null    float64
#  2   room_type                   977 non-null    object
#  3   room_shared                 977 non-null    bool
#  4   room_private                977 non-null    bool
#  5   person_capacity             977 non-null    float64
#  6   host_is_superhost           977 non-null    bool
#  7   multi                       977 non-null    int64
#  8   biz                         977 non-null    int64
#  9   cleanliness_rating          977 non-null    float64
#  10  guest_satisfaction_overall  977 non-null    float64
#  11  bedrooms                    977 non-null    int64
#  12  dist                        977 non-null    float64
# ...

# %%
amsterdam_weekends.describe()
# Out:
#        Unnamed: 0      realSum  person_capacity       multi         biz  \
# count  977.000000   977.000000       977.000000  977.000000  977.000000
# mean   488.000000   604.828018         2.769703    0.254862    0.094166
# std    282.179907   443.682821         1.019876    0.436007    0.292209
# min      0.000000   165.912872         2.000000    0.000000    0.000000
# 25%    244.000000   362.758653         2.000000    0.000000    0.000000
# 50%    488.000000   491.645771         2.000000    0.000000    0.000000
# 75%    732.000000   716.612378         4.000000    1.000000    0.000000
# max    976.000000  8130.668104         6.000000    1.000000    1.000000
#
#        cleanliness_rating  guest_satisfaction_overall    bedrooms        dist  \
# count          977.000000                  977.000000  977.000000  977.000000
# mean             9.470829                   94.685773    1.302968    2.806345
# std              0.830649                    6.632364    0.732949    2.036602
# ...

# %%
amsterdam_weekends['City'] = 'Amsterdam'

# %%
amsterdam_weekends.head(3)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  319.640053  Private room        False          True
# 1           1  347.995219  Private room        False          True
# 2           2  482.975183  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      0    1                 9.0  ...
# 1              2.0              False      0    1                 9.0  ...
# 2              4.0              False      0    1                 9.0  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0         1  4.763360    0.852117  110.906123         5.871971  136.982208
# 1         1  5.748310    3.651591   75.275937         3.985516   95.386468
# 2         2  0.384872    0.439852  493.272517        26.116521  875.114817
#
#    rest_index_norm      lng       lat       City
# ...

# %%
amsterdam_weekends['day_type'] = 'WeekEnd'

# %%
amsterdam_weekends.head(3)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  319.640053  Private room        False          True
# 1           1  347.995219  Private room        False          True
# 2           2  482.975183  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      0    1                 9.0  ...
# 1              2.0              False      0    1                 9.0  ...
# 2              4.0              False      0    1                 9.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0  4.763360    0.852117  110.906123         5.871971  136.982208
# 1  5.748310    3.651591   75.275937         3.985516   95.386468
# 2  0.384872    0.439852  493.272517        26.116521  875.114817
#
#    rest_index_norm      lng       lat       City  day_type
# 0        11.941560  4.84639  52.34137  Amsterdam   WeekEnd
# ...

# %%
amsterdam_weekends.to_csv('amsterdam_weekends.csv', index=False)

# %%
url="https://drive.google.com/file/d/1wJkttpesqEhjxmkt-ZVyYTKg8scyDdVw/view?usp=sharing"
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
amsterdam_weekdays = pd.read_csv(url)

# %%
amsterdam_weekdays['City'] = 'Amsterdam'

# %%
amsterdam_weekdays['day_type'] = 'WeekDay'

# %%
amsterdam_weekdays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1103 entries, 0 to 1102
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  1103 non-null   int64
#  1   realSum                     1103 non-null   float64
#  2   room_type                   1103 non-null   object
#  3   room_shared                 1103 non-null   bool
#  4   room_private                1103 non-null   bool
#  5   person_capacity             1103 non-null   float64
#  6   host_is_superhost           1103 non-null   bool
#  7   multi                       1103 non-null   int64
#  8   biz                         1103 non-null   int64
#  9   cleanliness_rating          1103 non-null   float64
#  10  guest_satisfaction_overall  1103 non-null   float64
#  11  bedrooms                    1103 non-null   int64
#  12  dist                        1103 non-null   float64
# ...

# %%
amsterdam_weekdays.to_csv('amsterdam_weekdays.csv', index=False)

# %%
url="https://drive.google.com/file/d/1q81__5AZUnuS8TxC8Z24QuqNKDmBHAkP/view?usp=sharing"
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
athens_weekdays = pd.read_csv(url)
athens_weekdays['City'] = 'Athens'
athens_weekdays['day_type'] = 'WeekDay'
athens_weekdays.head(3)
# Out:
#    Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0           0  129.824479  Entire home/apt        False         False
# 1           1  138.963748  Entire home/apt        False         False
# 2           2  156.304923  Entire home/apt        False         False
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              4.0              False      0    0                10.0  ...
# 1              4.0               True      1    0                10.0  ...
# 2              3.0               True      0    1                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0  2.813964    0.881890   55.348572         2.086871   78.778377
# 1  0.407293    0.304568  240.306654         9.060559  407.167696
# 2  1.237211    0.288488  199.507366         7.522257  395.967403
#
#    rest_index_norm       lng       lat    City  day_type
# 0         5.915160  23.76600  37.98300  Athens   WeekDay
# ...

# %%
athens_weekdays.info(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2653 entries, 0 to 2652
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  2653 non-null   int64
#  1   realSum                     2653 non-null   float64
#  2   room_type                   2653 non-null   object
#  3   room_shared                 2653 non-null   bool
#  4   room_private                2653 non-null   bool
#  5   person_capacity             2653 non-null   float64
#  6   host_is_superhost           2653 non-null   bool
#  7   multi                       2653 non-null   int64
#  8   biz                         2653 non-null   int64
#  9   cleanliness_rating          2653 non-null   float64
#  10  guest_satisfaction_overall  2653 non-null   float64
#  11  bedrooms                    2653 non-null   int64
#  12  dist                        2653 non-null   float64
# ...

# %%
athens_weekdays.to_csv('athens_weekdays.csv', index=False)

# %%
url="https://drive.google.com/file/d/1d5tW7S1VeT6on1gbekJHDVX4Z6O6tEfm/view?usp=sharing"
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
athens_weekends = pd.read_csv(url)
athens_weekends['City'] = 'Athens'
athens_weekends['day_type'] = 'WeekEnd'
athens_weekends.head(3)
# Out:
#    Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0           0  138.963748  Entire home/apt        False         False
# 1           1   91.627024  Entire home/apt        False         False
# 2           2   76.629250     Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              4.0               True      1    0                10.0  ...
# 1              4.0               True      1    0                10.0  ...
# 2              2.0              False      0    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0  0.407278    0.304570  240.306496         9.054205  407.167958
# 1  4.367463    0.297474   39.802996         1.499687   58.706522
# 2  2.194174    0.385247   78.734001         2.966519  113.326684
#
#    rest_index_norm       lng       lat    City  day_type
# 0         6.080622  23.73168  37.97776  Athens   WeekEnd
# ...

# %%
athens_weekends.info(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2627 entries, 0 to 2626
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  2627 non-null   int64
#  1   realSum                     2627 non-null   float64
#  2   room_type                   2627 non-null   object
#  3   room_shared                 2627 non-null   bool
#  4   room_private                2627 non-null   bool
#  5   person_capacity             2627 non-null   float64
#  6   host_is_superhost           2627 non-null   bool
#  7   multi                       2627 non-null   int64
#  8   biz                         2627 non-null   int64
#  9   cleanliness_rating          2627 non-null   float64
#  10  guest_satisfaction_overall  2627 non-null   float64
#  11  bedrooms                    2627 non-null   int64
#  12  dist                        2627 non-null   float64
# ...

# %%
athens_weekends.to_csv('athens_weekends.csv', index=False)

# %%
url="https://drive.google.com/file/d/1IhxgcCu5WBCN4CdGJHZ5zIHpjmjjQjaH/view?usp=sharing"
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
barcelona_weekdays = pd.read_csv(url)
barcelona_weekdays['City'] = 'Athens'
barcelona_weekdays['day_type'] = 'WeekDays'
barcelona_weekdays.head(3)
# Out:
#    Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0           0  474.317499  Entire home/apt        False         False
# 1           1  169.897829     Private room        False          True
# 2           2  161.984779     Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              4.0              False      0    1                10.0  ...
# 1              2.0               True      1    0                10.0  ...
# 2              4.0              False      0    1                 9.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0  1.111996    0.630491  526.469420        17.942927  915.587083
# 1  1.751839    0.124017  320.127526        10.910462  794.277350
# 2  1.670493    0.080322  344.073936        11.726595  840.673617
#
#    rest_index_norm      lng       lat    City  day_type
# 0        20.154890  2.17556  41.39624  Athens  WeekDays
# ...

# %%
barcelona_weekdays.info(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1555 entries, 0 to 1554
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  1555 non-null   int64
#  1   realSum                     1555 non-null   float64
#  2   room_type                   1555 non-null   object
#  3   room_shared                 1555 non-null   bool
#  4   room_private                1555 non-null   bool
#  5   person_capacity             1555 non-null   float64
#  6   host_is_superhost           1555 non-null   bool
#  7   multi                       1555 non-null   int64
#  8   biz                         1555 non-null   int64
#  9   cleanliness_rating          1555 non-null   float64
#  10  guest_satisfaction_overall  1555 non-null   float64
#  11  bedrooms                    1555 non-null   int64
#  12  dist                        1555 non-null   float64
# ...

# %%
barcelona_weekdays.to_csv('barcelona_weekdays.csv', index=False)

# %%
# !pip install mysql-connector-python
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sqlite3
conn = sqlite3.connect('neural_nebula_040.db')

# %%
amsterdam_weekends.to_sql('amsterdam_weekdays',conn,if_exists='replace',index=False)
# Out:
# 977

# %%
query ="SELECT * FROM amsterdam_weekdays LIMIT 5"
pd.read_sql(query,conn)
# Out:
#    Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 0           0   319.640053     Private room            0             1
# 1           1   347.995219     Private room            0             1
# 2           2   482.975183     Private room            0             1
# 3           3   485.552926     Private room            0             1
# 4           4  2771.541724  Entire home/apt            0             0
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0                  0      0    1                 9.0  ...
# 1              2.0                  0      0    1                 9.0  ...
# 2              4.0                  0      0    1                 9.0  ...
# 3              2.0                  1      0    0                10.0  ...
# 4              4.0                  1      0    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
combined_data_2 = pd.read_csv("C:\\Users\\Pallavi Work\\Desktop\\Pallavi\\Masai School\\Unit 3\\Construct Week\\combined_data_2.csv")
combined_data_2.head(3)
# Out:
#    Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0           0  536.396682  Entire home/apt        False         False
# 1           1  290.101594     Private room        False          True
# 2           2  445.754497  Entire home/apt        False         False
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              5.0              False      0    1                 9.0  ...
# 1              2.0               True      0    0                10.0  ...
# 2              4.0              False      0    1                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm   rest_index  \
# 0  1.351201    0.212346  390.776775        19.001549  1030.738507
# 1  0.699821    0.193710  518.478270        25.211044  1218.658866
# 2  0.968982    0.294343  432.689942        21.039580  1069.894793
#
#    rest_index_norm      lng       lat   city  day_type
# 0        47.550371  2.35900  48.86800  Paris  weekends
# ...

# %%
combined_data_1 = pd.read_csv("C:\\Users\\Pallavi Work\\Desktop\\Pallavi\\Masai School\\Unit 3\\Construct Week\\combined_data_1.csv")
combined_data_1.head(3)
# Out:
#    Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0           0  532.036214  Entire home/apt        False         False
# 1           1  169.897829     Private room        False          True
# 2           2  196.895292     Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              4.0              False      0    1                10.0  ...
# 1              2.0               True      1    0                10.0  ...
# 2              2.0              False      1    0                 9.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm   rest_index  \
# 0  1.111998    0.630504  526.471472        20.327672   915.591455
# 1  1.751831    0.124013  320.128264        12.360522   794.279660
# 2  0.621731    0.297516  503.354025        19.435081  1242.434221
#
#    rest_index_norm      lng       lat    city  date_type
# ...

# %%
combined_data_2 = combined_data_2.rename(columns={'city': 'City'})
combined_data_1 = combined_data_1.rename(columns={'city': 'City','date_type': 'day_type'})

# %%
combined_data_3 = pd.read_csv("C:\\Users\\Pallavi Work\\Desktop\\Pallavi\\Masai School\\Unit 3\\Construct Week\\combined_data_3.csv")
combined_data_3 = combined_data_3.rename(columns={'city': 'City'})
combined_data_3.head(3)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  138.133208  Private room        False          True
# 1           1  124.061914  Private room        False          True
# 2           2  194.183865  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0               True      1    0                10.0  ...
# 1              2.0               True      1    0                10.0  ...
# 2              4.0               True      1    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0  4.328029    0.298484   74.230170         2.450656  176.868292
# 1  4.465504    0.293603   72.570845         2.395875  173.909352
# 2  4.475232    0.167860   72.517895         2.394127  177.996137
#
#    rest_index_norm      lng       lat    City  day_type
# 0         7.910210 -9.14034  38.75137  Lisbon  weekdays
# ...

# %%
# Combine all DataFrames into a single DataFrame
combined_df = pd.concat([amsterdam_weekends,amsterdam_weekdays,athens_weekdays,athens_weekends,barcelona_weekdays,combined_data_2,combined_data_1,combined_data_3], axis=0, ignore_index=True)
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51707 entries, 0 to 51706
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  51707 non-null  int64
#  1   realSum                     51707 non-null  float64
#  2   room_type                   51707 non-null  object
#  3   room_shared                 51707 non-null  bool
#  4   room_private                51707 non-null  bool
#  5   person_capacity             51707 non-null  float64
#  6   host_is_superhost           51707 non-null  bool
#  7   multi                       51707 non-null  int64
#  8   biz                         51707 non-null  int64
#  9   cleanliness_rating          51707 non-null  float64
#  10  guest_satisfaction_overall  51707 non-null  float64
#  11  bedrooms                    51707 non-null  int64
#  12  dist                        51707 non-null  float64
# ...

# %%
combined_df.to_csv('combined_df.csv', index=False)

# %%
import warnings
warnings.filterwarnings('ignore')
from sqlalchemy import create_engine
import pandas as pd

# Database connection details
DATABASE_TYPE = 'mysql' 
DBAPI = 'mysqldb'  # Use 'mysqlconnector' instead of 'mysqldb'
USER = 'YourUser' 
PASSWORD = "YourPassword" 
HOST = 'HostName' 
PORT = '3306' 
DATABASE = 'Neural_Nebula_040' 

# Create the engine string
engine_string = f"{DATABASE_TYPE}+{DBAPI}://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"

# Create SQLAlchemy engine
engine = create_engine(engine_string)

# Connect to the database
conn = engine.connect()

# Assuming PerformanceRating is a DataFrame, you can save it to SQL
combined_df.to_sql('combined_df', con=engine, index=False, if_exists='replace')
# Out:
# 51707
